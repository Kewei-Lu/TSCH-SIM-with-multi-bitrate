# %%
import matplotlib.pyplot as plt
import json
import itertools
import re
import pandas as pd
import numpy as np

# %%
speed = [5704,"LA",29380]
change_time = [1198.73,1672.38,2157.22,2193.65,7200]
result = {}
cata = ["app_packets_received","PDR_in_percent","latency","duty_cycle","app_per_sec"]
#cata = ["app_packets_received",]
for i in speed:
    title = '{}'.format(i)
    result[title] = {}
    result[title]["app_packets_received"] = []
    result[title]["PDR_in_percent"] = []
    result[title]["latency"] = []
    result[title]["duty_cycle"] = []
    result[title]["app_per_sec"] = []
    
# 1000kbps
with open('./examples/mesh/results/high_throughput/1000kbps.txt','r') as f:
    text = f.read()
    app_packets_received = re.findall('app-packet-received in this period = (.+)',text)
    PDR_in_percent = re.findall('pdr=(.+),current_level=.+',text)
    latency = re.findall('latency in this period = (.+)',text)
    duty_cycle = re.findall('duty_cycle_joined_average=(.+)',text)
    app_per_sec = re.findall('app-packet-received per sec = (.+)',text)
    title = "5704"
    for item in cata:
        for t in range(len(app_packets_received)):
            result[title][str(item)].append(float(eval(item)[t]))

# %%
# LA
with open('./examples/mesh/results/high_throughput/LA.txt','r') as f:
    text = f.read()
    app_packets_received = re.findall('app-packet-received in this period = (.+)',text)
    PDR_in_percent = re.findall('pdr=(.+),current_level=.+',text)
    latency = re.findall('latency in this period = (.+)',text)
    duty_cycle = re.findall('duty_cycle_joined_average=(.+)',text)
    app_per_sec = re.findall('app-packet-received per sec = (.+)',text)
    title = "LA"
    for item in cata:
        for t in range(len(app_packets_received)):
            result[title][str(item)].append(float(eval(item)[t]))

# %%
x_axis = [50*i for i in range(1,len(latency)+1)]

# %%
# 50kbps
with open('./examples/mesh/results/high_throughput/50kbps.txt','r') as f:
    text = f.read()
    app_packets_received = re.findall('app-packet-received in this period = (.+)',text)
    PDR_in_percent = re.findall('pdr=(.+),current_level=.+',text)
    latency = re.findall('latency in this period = (.+)',text)
    duty_cycle = re.findall('duty_cycle_joined_average=(.+)',text)
    app_per_sec = re.findall('app-packet-received per sec = (.+)',text)
    title = "29380"
    for item in cata:
        for t in range(len(app_packets_received)):
            result[title][str(item)].append(float(eval(item)[t]))

# %%
x_axis_29380 = [50*i for i in range(1,len(latency)+1)]

# %%
# latency
plt.figure(figsize=(10,8))
plt.title('latency',fontsize=20)
plt.plot(x_axis,result['5704']['latency'],label='1000kbps')
plt.plot(x_axis,result['LA']['latency'],label='LA')
plt.plot(x_axis_29380,result['29380']['latency'],label='50kbps')
plt.xlabel('seconds(s)',fontsize=20)
plt.ylabel('latency(ms)',fontsize=20)
#plt.xlim(0, 10)
#plt.plot(period_range,processed_result['156900']['PAR'],label='8kbps')
plt.legend()
#plt.yticks([])
#plt.yscale('linear')
plt.yticks(np.arange(0,2.5,0.5))
#plt.savefig('./examples/mesh/single_model_diff_packet_period/PAR.jpg',bbox_inches = 'tight')
plt.savefig('./examples/mesh/example for high throughput/latency.jpg',bbox_inches = 'tight')
plt.show()

# %%
# latency
# subplot 1
plt.figure(figsize=(12,6))
plt.subplot(1, 2, 1)

plt.title('duty_cycle',fontsize=20)
plt.plot(x_axis[9:],result['5704']['duty_cycle'][9:],label='1000kbps')
plt.plot(x_axis[9:],result['LA']['duty_cycle'][9:],label='LA')

plt.xlabel('seconds(s)',fontsize=20)
plt.ylabel('duty_cycle(%)',fontsize=20)
#plt.xlim(0, 10)
#plt.plot(period_range,processed_result['156900']['PAR'],label='8kbps')
plt.legend()
#plt.yticks([])
#plt.yscale('linear')
plt.yticks(np.arange(0,1,0.2))
#plt.savefig('./examples/mesh/single_model_diff_packet_period/PAR.jpg',bbox_inches = 'tight')

plt.subplot(1, 2, 2)
#plt.figure(figsize=(8,6))
labels = '1000kbps','combination of bitrate'
plt.boxplot([
             result['5704']['duty_cycle'][9:],
             result['LA']['duty_cycle'][9:],
            ],labels = labels,showfliers=False)
plt.title('duty_cycle',fontsize=20)
plt.xlabel('seconds(s)',fontsize=20)
plt.ylabel('duty_cycle(%)',fontsize=20)
plt.xticks(rotation=90)
plt.savefig('./examples/mesh/example for high throughput/duty_cycle.jpg',bbox_inches = 'tight')

plt.show()

# %%
# throughput 
plt.figure(figsize=(15,5))
#plt.subplot(1, 2, 1)

plt.title('1000kbps',fontsize=20)
plt.plot(x_axis,[i * 60 for i in result['5704']['app_per_sec']],label='1000kbps')
plt.plot(x_axis,[i * 60 for i in result['LA']['app_per_sec']],label='combination of bitrate')
plt.xlabel('seconds(s)',fontsize=20)
plt.ylabel('packets per minute',fontsize=20)
plt.legend()

#plt.subplot(1, 2, 2)
#plt.figure(figsize=(10,8))
'''plt.title('LA',fontsize=20)

plt.xlabel('seconds(s)',fontsize=20)
plt.ylabel('app_per_min',fontsize=20)
plt.legend()'''
#plt.yticks(np.arange(5,180,15))
'''plt.subplot(1, 3, 3)
#plt.figure(figsize=(10,8))
plt.title('50kbps',fontsize=20)
plt.plot(x_axis_29380,[i * 60 for i in result['29380']['app_per_sec']],label='29380')
plt.xlabel('seconds(s)',fontsize=20)
plt.ylabel('app_per_sec',fontsize=20)
plt.legend()
'''
plt.savefig('./examples/mesh/example for high throughput/throughput.jpg',bbox_inches = 'tight')

plt.tight_layout()
plt.show()
